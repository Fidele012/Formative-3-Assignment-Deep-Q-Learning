# %% [markdown]
# <a href="https://colab.research.google.com/github/Fidele012/Formative-3-Assignment-Deep-Q-Learning/blob/Reine%2Fdqn-boxing/Formative_3_Reine_Mizero.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install stable-baselines3 gymnasium[atari] ale-py autorom torch matplotlib imageio[ffmpeg] tqdm
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.0/188.0 kB 6.7 MB/s eta 0:00:00
# ...

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-e96b1df4-5f67-484c-abf9-b03b67ab5a7c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e96b1df4-5f67-484c-abf9-b03b67ab5a7c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !python train.py --experiments Exp11_VeryLowLR_Stable_CNN Exp12_HighLR_FastLearn_CNN Exp13_LowGamma_ShortHorizon_CNN Exp14_VeryLowGamma_CNN Exp15_SmallBatch_FreqUpdate_CNN Exp16_VeryLargeBatch_CNN Exp17_MLP_LowGamma_Reference Exp18_MLP_LargeBatch_Comparison Exp19_MidGamma_MidLR_Balanced_CNN Exp20_FreqTargetUpdate_CNN
# Out:
# 2026-03-21 10:32:44.790158: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1774089164.810825    3924 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1774089164.817471    3924 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1774089164.834601    3924 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
from google.colab import files
files.download('dqn_model.zip')
files.download('results/final_observations.md')
files.download('results/experiment_comparison.png')

# %%
# !pip install -q "numpy>=2.0"
# !apt-get install -y xvfb ffmpeg > /dev/null

# %%
from google.colab import files
uploaded = files.upload()  # upload dqn_model.zip
# Out:
#      <input type="file" id="files-d08817f6-4ba8-4cc0-95d2-cf8d958dc524" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d08817f6-4ba8-4cc0-95d2-cf8d958dc524">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !python play.py --record --episodes 3 --no-render
# Out:
# 2026-03-18 16:42:29.336857: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-03-18 16:42:29.343363: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-03-18 16:42:29.359364: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1773852149.386161   10119 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1773852149.393652   10119 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
import glob
from google.colab import files
for f in glob.glob("videos/*.mp4"):
    files.download(f)
